# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime
from config import weather_api_key
import requests

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = list(zip(lats, lngs))
lat_lngs[:10]
# Out:
# [(-4.038730720296101, 105.60973760734458),
#  (-76.471071682688, -134.0975817017806),
#  (-26.353682377389077, -123.74677582167675),
#  (33.147852975934484, 92.75251665260492),
#  (48.75872769377378, -52.47408017906152),
#  (-43.88192541731058, 69.29092277541122),
#  (-10.670163601043654, -152.29055588822573),
#  (69.56029271875013, 142.631342461577),
#  (-57.498977495152026, -86.76804344017766),
#  (-11.648122801130327, 125.53267411905028)]

# %%
coordinates = list(lat_lngs)
coordinates[:10]
# Out:
# [(-4.038730720296101, 105.60973760734458),
#  (-76.471071682688, -134.0975817017806),
#  (-26.353682377389077, -123.74677582167675),
#  (33.147852975934484, 92.75251665260492),
#  (48.75872769377378, -52.47408017906152),
#  (-43.88192541731058, 69.29092277541122),
#  (-10.670163601043654, -152.29055588822573),
#  (69.56029271875013, 142.631342461577),
#  (-57.498977495152026, -86.76804344017766),
#  (-11.648122801130327, 125.53267411905028)]

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 630

# %%
# Create an empty list to hold the weather data.
city_data = []
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 13 | metro
# Processing Record 2 of Set 13 | rikitea
# Processing Record 3 of Set 13 | lasa
# Processing Record 4 of Set 13 | bonavista
# Processing Record 5 of Set 13 | souillac
# Processing Record 6 of Set 13 | faanui
# Processing Record 7 of Set 13 | deputatskiy
# Processing Record 8 of Set 13 | punta arenas
# Processing Record 9 of Set 13 | soe
# Processing Record 10 of Set 13 | centralia
# Processing Record 11 of Set 13 | vaini
# Processing Record 12 of Set 13 | albany
# Processing Record 13 of Set 13 | khatanga
# Processing Record 14 of Set 13 | ilulissat
# Processing Record 15 of Set 13 | terrace
# Processing Record 16 of Set 13 | oktyabrskiy
# Processing Record 17 of Set 13 | tiksi
# Processing Record 18 of Set 13 | cabo san lucas
# Processing Record 19 of Set 13 | srikakulam
# Processing Record 20 of Set 13 | mar del plata
# Processing Record 21 of Set 13 | fairbanks
# Processing Record 22 of Set 13 | talnakh
# Processing Record 23 of Set 13 | hermanus
# Processing Record 24 of Set 13 | ushuaia
# Processing Record 25 of Set 13 | busselton
# Processing Record 26 of Set 13 | tiarei
# Processing Record 27 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 28 of Set 13 | georgetown
# Processing Record 29 of Set 13 | aklavik
# Processing Record 30 of Set 13 | norman wells
# Processing Record 31 of Set 13 | luderitz
# Processing Record 32 of Set 13 | taoudenni
# Processing Record 33 of Set 13 | thompson
# Processing Record 34 of Set 13 | pevek
# Processing Record 35 of Set 13 | adrar
# Processing Record 36 of Set 13 | cape town
# Processing Record 37 of Set 13 | yellowknife
# Processing Record 38 of Set 13 | san martin jilotepeque
# Processing Record 39 of Set 13 | port blair
# Processing Record 40 of Set 13 | pincher creek
# Processing Record 41 of Set 13 | carnarvon
# Processing Record 42 of Set 13 | qaanaaq
# Processing Record 43 of Set 13 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 13 | bredasdorp
# Processing Record 45 of Set 13 | sawakin
# Processing Record 46 of Set 13 | labuhan
# Processing Record 47 of Set 13 | narsaq
# Processing Record 48 of Set 13 | emerald
# Processing Record 49 of Set 13 | new norfolk
# Processing Record 50 of Set 13 | atuona
# Processing Record 1 of Set 14 | east london
# Processing Record 2 of Set 14 | puerto ayora
# Processing Record 3 of Set 14 | hasaki
# Processing Record 4 of Set 14 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 14 | bluff
# Processing Record 6 of Set 14 | tevriz
# Processing Record 7 of Set 14 | beian
# Processing Record 8 of Set 14 | corn island
# Processing Record 9 of Set 14 | cam pha
# City not found. Skipping...
# Processing Record 10 of Set 14 | vostok
# Processing Record 11 of Set 14 | jiuquan
# Processing Record 12 of Set 14 | pacifica
# Processing Record 13 of Set 14 | kodiak
# Processing Record 14 of Set 14 | senovo
# Processing Record 15 of Set 14 | jamestown
# Processing Record 16 of Set 14 | dikson
# Processing Record 17 of Set 14 | ylojarvi
# Processing Record 18 of Set 14 | port alfred
# Processing Record 19 of Set 14 | buraydah
# Processing Record 20 of Set 14 | eyl
# Processing Record 21 of Set 14 | lugovoy
# Processing Record 22 of Set 14 | castro
# Processing Record 23 of Set 14 | muzhi
# Processing Record 24 of Set 14 | troitskoye
# Processing Record 25 of Set 14 | portland
# Processing Record 26 of Set 14 | ponta delgada
# Processing Record 27 of Set 14 | qasigiannguit
# Processing Record 28 of Set 14 | barrow
# Processing Record 29 of Set 14 | chapais
# Processing Record 30 of Set 14 | paamiut
# Processing Record 31 of Set 14 | upernavik
# Processing Record 32 of Set 14 | tecoanapa
# Processing Record 33 of Set 14 | canandaigua
# Processing Record 34 of Set 14 | boa viagem
# Processing Record 35 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 14 | hilo
# Processing Record 37 of Set 14 | chistogorskiy
# Processing Record 38 of Set 14 | portales
# Processing Record 39 of Set 14 | saint-philippe
# Processing Record 40 of Set 14 | arraial do cabo
# Processing Record 41 of Set 14 | butaritari
# Processing Record 42 of Set 14 | ayr
# Processing Record 43 of Set 14 | torbay
# Processing Record 44 of Set 14 | meadow lake
# Processing Record 45 of Set 14 | pisco
# Processing Record 46 of Set 14 | santa maria
# Processing Record 47 of Set 14 | sivaki
# Processing Record 48 of Set 14 | kapaa
# Processing Record 49 of Set 14 | gorontalo
# Processing Record 50 of Set 14 | nyurba
# Processing Record 1 of Set 15 | roald
# Processing Record 2 of Set 15 | bud
# Processing Record 3 of Set 15 | biloela
# Processing Record 4 of Set 15 | bengkulu
# Processing Record 5 of Set 15 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 15 | mataura
# Processing Record 7 of Set 15 | clyde river
# Processing Record 8 of Set 15 | pemba
# Processing Record 9 of Set 15 | datong
# Processing Record 10 of Set 15 | tasiilaq
# Processing Record 11 of Set 15 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 15 | at-bashi
# Processing Record 13 of Set 15 | plettenberg bay
# Processing Record 14 of Set 15 | parlakimidi
# Processing Record 15 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 16 of Set 15 | japura
# Processing Record 17 of Set 15 | holguin
# Processing Record 18 of Set 15 | mugur-aksy
# Processing Record 19 of Set 15 | weyburn
# Processing Record 20 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 15 | guerrero negro
# Processing Record 22 of Set 15 | xichang
# Processing Record 23 of Set 15 | kholodnyy
# Processing Record 24 of Set 15 | kirakira
# Processing Record 25 of Set 15 | arlit
# Processing Record 26 of Set 15 | severo-kurilsk
# Processing Record 27 of Set 15 | farkhor
# Processing Record 28 of Set 15 | hobart
# Processing Record 29 of Set 15 | ust-tarka
# Processing Record 30 of Set 15 | hailey
# Processing Record 31 of Set 15 | ucluelet
# Processing Record 32 of Set 15 | bambous virieux
# Processing Record 33 of Set 15 | hillsboro
# Processing Record 34 of Set 15 | okhotsk
# Processing Record 35 of Set 15 | san cristobal
# Processing Record 36 of Set 15 | eureka
# Processing Record 37 of Set 15 | fort atkinson
# Processing Record 38 of Set 15 | cidreira
# Processing Record 39 of Set 15 | kaputa
# Processing Record 40 of Set 15 | ribeira grande
# Processing Record 41 of Set 15 | macherla
# Processing Record 42 of Set 15 | los llanos de aridane
# Processing Record 43 of Set 15 | denpasar
# Processing Record 44 of Set 15 | kruisfontein
# Processing Record 45 of Set 15 | svetlaya
# Processing Record 46 of Set 15 | altay
# Processing Record 47 of Set 15 | praia da vitoria
# Processing Record 48 of Set 15 | luangwa
# Processing Record 49 of Set 15 | sitka
# Processing Record 50 of Set 15 | exeter
# Processing Record 1 of Set 16 | atar
# Processing Record 2 of Set 16 | saldanha
# Processing Record 3 of Set 16 | leghorn
# City not found. Skipping...
# Processing Record 4 of Set 16 | cherskiy
# Processing Record 5 of Set 16 | fayaoue
# Processing Record 6 of Set 16 | cayenne
# Processing Record 7 of Set 16 | avarua
# Processing Record 8 of Set 16 | howard springs
# Processing Record 9 of Set 16 | sovetskiy
# Processing Record 10 of Set 16 | lanquin
# Processing Record 11 of Set 16 | natal
# Processing Record 12 of Set 16 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 16 | tyrma
# Processing Record 14 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 16 | caucaia
# Processing Record 16 of Set 16 | chuy
# Processing Record 17 of Set 16 | agapovka
# Processing Record 18 of Set 16 | sakakah
# Processing Record 19 of Set 16 | ponta do sol
# Processing Record 20 of Set 16 | el estor
# Processing Record 21 of Set 16 | chokurdakh
# Processing Record 22 of Set 16 | kavieng
# Processing Record 23 of Set 16 | broken hill
# Processing Record 24 of Set 16 | aksu
# Processing Record 25 of Set 16 | kitui
# Processing Record 26 of Set 16 | kalmar
# Processing Record 27 of Set 16 | mount gambier
# Processing Record 28 of Set 16 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 16 | susurluk
# Processing Record 30 of Set 16 | ziway
# Processing Record 31 of Set 16 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 16 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 16 | provideniya
# Processing Record 34 of Set 16 | bethel
# Processing Record 35 of Set 16 | pacific grove
# Processing Record 36 of Set 16 | zhezkazgan
# Processing Record 37 of Set 16 | dingle
# Processing Record 38 of Set 16 | thinadhoo
# Processing Record 39 of Set 16 | sistranda
# Processing Record 40 of Set 16 | mareeba
# Processing Record 41 of Set 16 | vila velha
# Processing Record 42 of Set 16 | bac lieu
# Processing Record 43 of Set 16 | zolochiv
# Processing Record 44 of Set 16 | kindu
# Processing Record 45 of Set 16 | oksfjord
# Processing Record 46 of Set 16 | nanortalik
# Processing Record 47 of Set 16 | bestobe
# Processing Record 48 of Set 16 | mujiayingzi
# Processing Record 49 of Set 16 | sambava
# Processing Record 50 of Set 16 | biltine
# Processing Record 1 of Set 17 | port elizabeth
# Processing Record 2 of Set 17 | ambulu
# Processing Record 3 of Set 17 | makakilo city
# Processing Record 4 of Set 17 | grindavik
# Processing Record 5 of Set 17 | hithadhoo
# Processing Record 6 of Set 17 | tuktoyaktuk
# Processing Record 7 of Set 17 | surt
# Processing Record 8 of Set 17 | talawdi
# City not found. Skipping...
# Processing Record 9 of Set 17 | dubti
# Processing Record 10 of Set 17 | lavrentiya
# Processing Record 11 of Set 17 | mahibadhoo
# Processing Record 12 of Set 17 | geraldton
# Processing Record 13 of Set 17 | airai
# Processing Record 14 of Set 17 | longyearbyen
# Processing Record 15 of Set 17 | arzachena
# Processing Record 16 of Set 17 | kirov
# Processing Record 17 of Set 17 | victoria
# Processing Record 18 of Set 17 | husavik
# Processing Record 19 of Set 17 | codrington
# Processing Record 20 of Set 17 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 17 | esperance
# Processing Record 22 of Set 17 | hamilton
# Processing Record 23 of Set 17 | kaitangata
# Processing Record 24 of Set 17 | santiago
# Processing Record 25 of Set 17 | poum
# Processing Record 26 of Set 17 | nautla
# Processing Record 27 of Set 17 | rocha
# Processing Record 28 of Set 17 | ube
# Processing Record 29 of Set 17 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 17 | dunedin
# Processing Record 31 of Set 17 | sfantu gheorghe
# Processing Record 32 of Set 17 | fortuna
# Processing Record 33 of Set 17 | davila
# Processing Record 34 of Set 17 | usinsk
# Processing Record 35 of Set 17 | port lincoln
# Processing Record 36 of Set 17 | bababe
# City not found. Skipping...
# Processing Record 37 of Set 17 | komarno
# Processing Record 38 of Set 17 | brae
# Processing Record 39 of Set 17 | coihaique
# Processing Record 40 of Set 17 | darab
# Processing Record 41 of Set 17 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 17 | kamenskiy
# Processing Record 43 of Set 17 | vaitape
# Processing Record 44 of Set 17 | port macquarie
# Processing Record 45 of Set 17 | hurfeish
# Processing Record 46 of Set 17 | san carlos
# Processing Record 47 of Set 17 | haines junction
# Processing Record 48 of Set 17 | veraval
# Processing Record 49 of Set 17 | sept-iles
# Processing Record 50 of Set 17 | san lawrenz
# Processing Record 1 of Set 18 | finnsnes
# Processing Record 2 of Set 18 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 18 | yurkivka
# Processing Record 4 of Set 18 | dauphin
# Processing Record 5 of Set 18 | huarmey
# Processing Record 6 of Set 18 | kemin
# Processing Record 7 of Set 18 | bose
# Processing Record 8 of Set 18 | rabat
# Processing Record 9 of Set 18 | gilbues
# Processing Record 10 of Set 18 | maumere
# Processing Record 11 of Set 18 | lhokseumawe
# Processing Record 12 of Set 18 | matara
# Processing Record 13 of Set 18 | pangnirtung
# Processing Record 14 of Set 18 | ambunti
# Processing Record 15 of Set 18 | joroan
# Processing Record 16 of Set 18 | batagay-alyta
# Processing Record 17 of Set 18 | abu dhabi
# Processing Record 18 of Set 18 | lebu
# Processing Record 19 of Set 18 | namibe
# Processing Record 20 of Set 18 | mahebourg
# Processing Record 21 of Set 18 | nikolskoye
# Processing Record 22 of Set 18 | flinders
# Processing Record 23 of Set 18 | tarudant
# City not found. Skipping...
# Processing Record 24 of Set 18 | igurubi
# Processing Record 25 of Set 18 | karmaskaly
# Processing Record 26 of Set 18 | naberera
# Processing Record 27 of Set 18 | cockburn town
# Processing Record 28 of Set 18 | talipparamba
# Processing Record 29 of Set 18 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 18 | castanhal
# Processing Record 31 of Set 18 | coahuayana
# Processing Record 32 of Set 18 | pontianak
# Processing Record 33 of Set 18 | barra patuca
# Processing Record 34 of Set 18 | presidencia roque saenz pena
# Processing Record 35 of Set 18 | gouyave
# Processing Record 36 of Set 18 | hunza
# City not found. Skipping...
# Processing Record 37 of Set 18 | beyneu
# Processing Record 38 of Set 18 | nefteyugansk
# Processing Record 39 of Set 18 | banamba
# Processing Record 40 of Set 18 | baoding
# Processing Record 41 of Set 18 | havelock
# Processing Record 42 of Set 18 | yuanping
# Processing Record 43 of Set 18 | warren
# Processing Record 44 of Set 18 | hovd
# Processing Record 45 of Set 18 | moussoro
# Processing Record 46 of Set 18 | chabahar
# Processing Record 47 of Set 18 | timizart
# Processing Record 48 of Set 18 | astoria
# Processing Record 49 of Set 18 | chicama
# Processing Record 50 of Set 18 | manta
# Processing Record 1 of Set 19 | xapuri
# Processing Record 2 of Set 19 | saint-francois
# Processing Record 3 of Set 19 | comodoro rivadavia
# Processing Record 4 of Set 19 | ayorou
# Processing Record 5 of Set 19 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 19 | kjollefjord
# Processing Record 7 of Set 19 | hailar
# Processing Record 8 of Set 19 | ouadda
# Processing Record 9 of Set 19 | walvis bay
# Processing Record 10 of Set 19 | marawi
# Processing Record 11 of Set 19 | hobyo
# Processing Record 12 of Set 19 | bilma
# Processing Record 13 of Set 19 | porto novo
# Processing Record 14 of Set 19 | la seyne-sur-mer
# Processing Record 15 of Set 19 | pushkino
# Processing Record 16 of Set 19 | galiwinku
# City not found. Skipping...
# Processing Record 17 of Set 19 | polunochnoye
# Processing Record 18 of Set 19 | zamora
# Processing Record 19 of Set 19 | le mars
# Processing Record 20 of Set 19 | agadez
# Processing Record 21 of Set 19 | fort-shevchenko
# Processing Record 22 of Set 19 | prince rupert
# Processing Record 23 of Set 19 | fort nelson
# Processing Record 24 of Set 19 | bajil
# Processing Record 25 of Set 19 | ndele
# Processing Record 26 of Set 19 | naze
# Processing Record 27 of Set 19 | kudat
# Processing Record 28 of Set 19 | dobrinka
# Processing Record 29 of Set 19 | pimentel
# Processing Record 30 of Set 19 | sexsmith
# Processing Record 31 of Set 19 | hvide sande
# Processing Record 32 of Set 19 | ust-tsilma
# Processing Record 33 of Set 19 | tabou
# Processing Record 34 of Set 19 | reconquista
# Processing Record 35 of Set 19 | broome
# Processing Record 36 of Set 19 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 19 | houma
# Processing Record 38 of Set 19 | sahiwal
# Processing Record 39 of Set 19 | tezu
# Processing Record 40 of Set 19 | hatton
# Processing Record 41 of Set 19 | stromness
# Processing Record 42 of Set 19 | kavaratti
# Processing Record 43 of Set 19 | ola
# Processing Record 44 of Set 19 | kloulklubed
# Processing Record 45 of Set 19 | katsuura
# Processing Record 46 of Set 19 | mbour
# Processing Record 47 of Set 19 | sheltozero
# Processing Record 48 of Set 19 | requena
# Processing Record 49 of Set 19 | novikovo
# Processing Record 50 of Set 19 | malpe
# Processing Record 1 of Set 20 | tingrela
# City not found. Skipping...
# Processing Record 2 of Set 20 | katima mulilo
# Processing Record 3 of Set 20 | asau
# Processing Record 4 of Set 20 | tautira
# Processing Record 5 of Set 20 | ostrovnoy
# Processing Record 6 of Set 20 | kumluca
# Processing Record 7 of Set 20 | isangel
# Processing Record 8 of Set 20 | tazmalt
# Processing Record 9 of Set 20 | necochea
# Processing Record 10 of Set 20 | poykovskiy
# Processing Record 11 of Set 20 | ruatoria
# City not found. Skipping...
# Processing Record 12 of Set 20 | ankazoabo
# Processing Record 13 of Set 20 | karpuninskiy
# City not found. Skipping...
# Processing Record 14 of Set 20 | vernon
# Processing Record 15 of Set 20 | wamba
# Processing Record 16 of Set 20 | coquimbo
# Processing Record 17 of Set 20 | ijaki
# City not found. Skipping...
# Processing Record 18 of Set 20 | lamu
# Processing Record 19 of Set 20 | chippewa falls
# Processing Record 20 of Set 20 | evensk
# Processing Record 21 of Set 20 | maceio
# Processing Record 22 of Set 20 | vestmannaeyjar
# Processing Record 23 of Set 20 | marsa matruh
# Processing Record 24 of Set 20 | la rioja
# Processing Record 25 of Set 20 | ituiutaba
# Processing Record 26 of Set 20 | namatanai
# Processing Record 27 of Set 20 | kautokeino
# Processing Record 28 of Set 20 | tatawin
# Processing Record 29 of Set 20 | waitati
# Processing Record 30 of Set 20 | the valley
# Processing Record 31 of Set 20 | pasighat
# Processing Record 32 of Set 20 | rodrigues alves
# Processing Record 33 of Set 20 | westport
# Processing Record 34 of Set 20 | sur
# Processing Record 35 of Set 20 | omsukchan
# Processing Record 36 of Set 20 | kirkwood
# Processing Record 37 of Set 20 | college
# Processing Record 38 of Set 20 | quang ngai
# Processing Record 39 of Set 20 | cheney
# Processing Record 40 of Set 20 | guilin
# Processing Record 41 of Set 20 | solginskiy
# Processing Record 42 of Set 20 | nioki
# Processing Record 43 of Set 20 | valpoi
# Processing Record 44 of Set 20 | jiaocheng
# Processing Record 45 of Set 20 | yialos
# City not found. Skipping...
# Processing Record 46 of Set 20 | urtaaul
# City not found. Skipping...
# Processing Record 47 of Set 20 | kashi
# Processing Record 48 of Set 20 | balkanabat
# Processing Record 49 of Set 20 | juneau
# Processing Record 50 of Set 20 | caravelas
# Processing Record 1 of Set 21 | nuristan
# Processing Record 2 of Set 21 | ovalle
# Processing Record 3 of Set 21 | dir
# Processing Record 4 of Set 21 | tual
# Processing Record 5 of Set 21 | viedma
# Processing Record 6 of Set 21 | raudeberg
# Processing Record 7 of Set 21 | port-gentil
# Processing Record 8 of Set 21 | gigmoto
# Processing Record 9 of Set 21 | san carlos de bariloche
# Processing Record 10 of Set 21 | grand gaube
# Processing Record 11 of Set 21 | carauari
# Processing Record 12 of Set 21 | sao mateus
# Processing Record 13 of Set 21 | isabela
# Processing Record 14 of Set 21 | saskylakh
# Processing Record 15 of Set 21 | rudersdorf
# Processing Record 16 of Set 21 | nikolayevka
# Processing Record 17 of Set 21 | tutoia
# Processing Record 18 of Set 21 | merauke
# Processing Record 19 of Set 21 | lar
# Processing Record 20 of Set 21 | ilebo
# Processing Record 21 of Set 21 | farmington
# Processing Record 22 of Set 21 | sao filipe
# Processing Record 23 of Set 21 | hambantota
# Processing Record 24 of Set 21 | piacabucu
# Processing Record 25 of Set 21 | preston
# Processing Record 26 of Set 21 | leo
# Processing Record 27 of Set 21 | inhambane
# Processing Record 28 of Set 21 | shingu
# Processing Record 29 of Set 21 | tuatapere
# Processing Record 30 of Set 21 | bisalpur
# Processing Record 31 of Set 21 | abu samrah
# Processing Record 32 of Set 21 | karratha
# Processing Record 33 of Set 21 | moose factory
# Processing Record 34 of Set 21 | pinsk
# Processing Record 35 of Set 21 | illela
# Processing Record 36 of Set 21 | launceston
# Processing Record 37 of Set 21 | margate
# Processing Record 38 of Set 21 | davenport
# Processing Record 39 of Set 21 | boysun
# Processing Record 40 of Set 21 | fallon
# Processing Record 41 of Set 21 | vanavara
# Processing Record 42 of Set 21 | ahipara
# Processing Record 43 of Set 21 | nacala
# Processing Record 44 of Set 21 | belyy yar
# Processing Record 45 of Set 21 | cap-aux-meules
# Processing Record 46 of Set 21 | yeppoon
# Processing Record 47 of Set 21 | avera
# Processing Record 48 of Set 21 | rio gallegos
# Processing Record 49 of Set 21 | biak
# Processing Record 50 of Set 21 | pastos bons
# Processing Record 1 of Set 22 | port augusta
# Processing Record 2 of Set 22 | mahanoro
# Processing Record 3 of Set 22 | porbandar
# Processing Record 4 of Set 22 | port keats
# Processing Record 5 of Set 22 | te anau
# Processing Record 6 of Set 22 | bilibino
# Processing Record 7 of Set 22 | karamea
# City not found. Skipping...
# Processing Record 8 of Set 22 | mirandopolis
# Processing Record 9 of Set 22 | kosh-agach
# Processing Record 10 of Set 22 | shizunai
# Processing Record 11 of Set 22 | sabha
# Processing Record 12 of Set 22 | vite
# Processing Record 13 of Set 22 | san patricio
# Processing Record 14 of Set 22 | chunhuhub
# Processing Record 15 of Set 22 | gamba
# Processing Record 16 of Set 22 | ancud
# Processing Record 17 of Set 22 | amga
# Processing Record 18 of Set 22 | vrangel
# Processing Record 19 of Set 22 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 22 | dunda
# Processing Record 21 of Set 22 | sangar
# Processing Record 22 of Set 22 | yerbogachen
# Processing Record 23 of Set 22 | ronda
# Processing Record 24 of Set 22 | nueva loja
# Processing Record 25 of Set 22 | port hardy
# Processing Record 26 of Set 22 | torbeyevo
# Processing Record 27 of Set 22 | kahramanmaras
# Processing Record 28 of Set 22 | hofn
# Processing Record 29 of Set 22 | mount isa
# Processing Record 30 of Set 22 | vila franca do campo
# Processing Record 31 of Set 22 | yar-sale
# Processing Record 32 of Set 22 | dzilam gonzalez
# Processing Record 33 of Set 22 | ngukurr
# City not found. Skipping...
# Processing Record 34 of Set 22 | dalbandin
# Processing Record 35 of Set 22 | saint-augustin
# Processing Record 36 of Set 22 | manbij
# Processing Record 37 of Set 22 | langres
# Processing Record 38 of Set 22 | tashara
# Processing Record 39 of Set 22 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 40 of Set 22 | asandh
# Processing Record 41 of Set 22 | lompoc
# Processing Record 42 of Set 22 | tonneins
# Processing Record 43 of Set 22 | puerto escondido
# Processing Record 44 of Set 22 | quatre cocos
# Processing Record 45 of Set 22 | providencia
# Processing Record 46 of Set 22 | creston
# Processing Record 47 of Set 22 | khandyga
# Processing Record 48 of Set 22 | tianpeng
# Processing Record 49 of Set 22 | yunjinghong
# City not found. Skipping...
# Processing Record 50 of Set 22 | jarjis
# City not found. Skipping...
# Processing Record 1 of Set 23 | touros
# Processing Record 2 of Set 23 | baicheng
# Processing Record 3 of Set 23 | praia
# Processing Record 4 of Set 23 | ketchikan
# Processing Record 5 of Set 23 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 23 | luena
# Processing Record 7 of Set 23 | tawkar
# City not found. Skipping...
# Processing Record 8 of Set 23 | zhigansk
# Processing Record 9 of Set 23 | lac-megantic
# Processing Record 10 of Set 23 | ghanzi
# Processing Record 11 of Set 23 | sicuani
# Processing Record 12 of Set 23 | panjab
# Processing Record 13 of Set 23 | matadi
# Processing Record 14 of Set 23 | doha
# Processing Record 15 of Set 23 | sayaxche
# Processing Record 16 of Set 23 | cedar city
# Processing Record 17 of Set 23 | olkusz
# Processing Record 18 of Set 23 | vardo
# Processing Record 19 of Set 23 | saint george
# Processing Record 20 of Set 23 | lakatoro
# Processing Record 21 of Set 23 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 23 | araguacu
# Processing Record 23 of Set 23 | grajau
# Processing Record 24 of Set 23 | jansath
# Processing Record 25 of Set 23 | san lorenzo
# Processing Record 26 of Set 23 | damaturu
# Processing Record 27 of Set 23 | neyshabur
# Processing Record 28 of Set 23 | bitung
# Processing Record 29 of Set 23 | san ignacio
# Processing Record 30 of Set 23 | san andres
# Processing Record 31 of Set 23 | ust-maya
# Processing Record 32 of Set 23 | san antonio
# Processing Record 33 of Set 23 | tapaua
# City not found. Skipping...
# Processing Record 34 of Set 23 | camacha
# Processing Record 35 of Set 23 | huazolotitlan
# City not found. Skipping...
# Processing Record 36 of Set 23 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 23 | kalangala
# Processing Record 38 of Set 23 | chapaevsk
# Processing Record 39 of Set 23 | khonuu
# City not found. Skipping...
# Processing Record 40 of Set 23 | tilichiki
# Processing Record 41 of Set 23 | labutta
# City not found. Skipping...
# Processing Record 42 of Set 23 | okrika
# Processing Record 43 of Set 23 | marzuq
# Processing Record 44 of Set 23 | garowe
# Processing Record 45 of Set 23 | hirara
# Processing Record 46 of Set 23 | udachnyy
# Processing Record 47 of Set 23 | moron
# Processing Record 48 of Set 23 | sao felix do xingu
# Processing Record 49 of Set 23 | salalah
# Processing Record 50 of Set 23 | sokoto
# Processing Record 1 of Set 24 | krasnogorsk
# Processing Record 2 of Set 24 | yenagoa
# Processing Record 3 of Set 24 | olafsvik
# Processing Record 4 of Set 24 | hami
# Processing Record 5 of Set 24 | strezhevoy
# Processing Record 6 of Set 24 | dudinka
# Processing Record 7 of Set 24 | buta
# Processing Record 8 of Set 24 | yuzhno-kurilsk
# Processing Record 9 of Set 24 | flagstaff
# Processing Record 10 of Set 24 | jesus carranza
# Processing Record 11 of Set 24 | artyom
# Processing Record 12 of Set 24 | teahupoo
# Processing Record 13 of Set 24 | dickinson
# Processing Record 14 of Set 24 | morki
# Processing Record 15 of Set 24 | mbuyapey
# Processing Record 16 of Set 24 | kirensk
# Processing Record 17 of Set 24 | mackay
# Processing Record 18 of Set 24 | oyama
# Processing Record 19 of Set 24 | taltal
# Processing Record 20 of Set 24 | bluefields
# Processing Record 21 of Set 24 | lagoa
# Processing Record 22 of Set 24 | pringsewu
# Processing Record 23 of Set 24 | san jose
# Processing Record 24 of Set 24 | clinton
# Processing Record 25 of Set 24 | seoul
# Processing Record 26 of Set 24 | pundaguitan
# Processing Record 27 of Set 24 | lorengau
# Processing Record 28 of Set 24 | bocaiuva
# Processing Record 29 of Set 24 | camana
# Processing Record 30 of Set 24 | bayir
# Processing Record 31 of Set 24 | belmonte
# Processing Record 32 of Set 24 | la ronge
# Processing Record 33 of Set 24 | petropavlovskoye
# Processing Record 34 of Set 24 | lomza
# Processing Record 35 of Set 24 | kushima
# Processing Record 36 of Set 24 | kwinana
# Processing Record 37 of Set 24 | klaksvik
# Processing Record 38 of Set 24 | radovitskiy
# Processing Record 39 of Set 24 | ife
# Processing Record 40 of Set 24 | mwinilunga
# Processing Record 41 of Set 24 | obama
# Processing Record 42 of Set 24 | carora
# Processing Record 43 of Set 24 | champerico
# Processing Record 44 of Set 24 | nsoko
# Processing Record 45 of Set 24 | phan rang
# City not found. Skipping...
# Processing Record 46 of Set 24 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 24 | taraz
# Processing Record 48 of Set 24 | xinxiang
# Processing Record 49 of Set 24 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 50 of Set 24 | glendive
# Processing Record 1 of Set 25 | labuan
# Processing Record 2 of Set 25 | aguascalientes
# Processing Record 3 of Set 25 | khani
# Processing Record 4 of Set 25 | tazovskiy
# Processing Record 5 of Set 25 | seddon
# Processing Record 6 of Set 25 | sao miguel do araguaia
# Processing Record 7 of Set 25 | tabuk
# Processing Record 8 of Set 25 | port-cartier
# Processing Record 9 of Set 25 | xinzhou
# Processing Record 10 of Set 25 | vao
# Processing Record 11 of Set 25 | mehamn
# Processing Record 12 of Set 25 | kailua
# Processing Record 13 of Set 25 | san fernando
# Processing Record 14 of Set 25 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 25 | genhe
# Processing Record 16 of Set 25 | banda aceh
# Processing Record 17 of Set 25 | uvalde
# Processing Record 18 of Set 25 | leskolovo
# Processing Record 19 of Set 25 | san ramon
# Processing Record 20 of Set 25 | menongue
# Processing Record 21 of Set 25 | eskasem
# City not found. Skipping...
# Processing Record 22 of Set 25 | kulachi
# Processing Record 23 of Set 25 | basco
# Processing Record 24 of Set 25 | baykit
# Processing Record 25 of Set 25 | dangriga
# Processing Record 26 of Set 25 | samarai
# Processing Record 27 of Set 25 | rongcheng
# Processing Record 28 of Set 25 | pangody
# Processing Record 29 of Set 25 | liverpool
# Processing Record 30 of Set 25 | marshall
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 579

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Metro  -5.1131  105.3067     78.13        84          73
# 1       Rikitea -23.1203 -134.9692     78.87        75          31
# 2          Lasa  46.6166   10.7002     28.00        80          75
# 3     Bonavista  48.6499  -53.1147     39.00        93         100
# 4      Souillac -20.5167   57.5167     78.80        83          40
# 5        Faanui -16.4833 -151.7500     82.08        74           0
# 6   Deputatskiy  69.3000  139.9000    -36.22        85          91
# 7  Punta Arenas -53.1500  -70.9167     53.60        66           0
# 8           Soe  -9.8607  124.2840     76.69        77          32
# 9     Centralia  46.7162 -122.9543     50.00        93          90
#
#    Wind Speed Country                 Date       Description
# 0       11.97      ID  2021-01-18 01:17:15     broken clouds
# 1       12.17      PF  2021-01-18 01:17:15  scattered clouds
# 2        9.22      IT  2021-01-18 01:17:15     broken clouds
# 3        4.61      CA  2021-01-18 01:17:15     moderate rain
# 4       11.50      MU  2021-01-18 01:05:38  scattered clouds
# 5       12.39      PF  2021-01-18 01:11:51         clear sky
# 6        1.07      RU  2021-01-18 01:17:16   overcast clouds
# 7       31.07      CL  2021-01-18 01:12:45         clear sky
# 8        3.58      ID  2021-01-18 01:17:16        light rain
# 9        6.91      US  2021-01-18 01:14:51   overcast clouds

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0         Metro      ID  2021-01-18 01:17:15  -5.1131  105.3067     78.13
# 1       Rikitea      PF  2021-01-18 01:17:15 -23.1203 -134.9692     78.87
# 2          Lasa      IT  2021-01-18 01:17:15  46.6166   10.7002     28.00
# 3     Bonavista      CA  2021-01-18 01:17:15  48.6499  -53.1147     39.00
# 4      Souillac      MU  2021-01-18 01:05:38 -20.5167   57.5167     78.80
# 5        Faanui      PF  2021-01-18 01:11:51 -16.4833 -151.7500     82.08
# 6   Deputatskiy      RU  2021-01-18 01:17:16  69.3000  139.9000    -36.22
# 7  Punta Arenas      CL  2021-01-18 01:12:45 -53.1500  -70.9167     53.60
# 8           Soe      ID  2021-01-18 01:17:16  -9.8607  124.2840     76.69
# 9     Centralia      US  2021-01-18 01:14:51  46.7162 -122.9543     50.00
#
#    Humidity  Cloudiness  Wind Speed       Description
# 0        84          73       11.97     broken clouds
# 1        75          31       12.17  scattered clouds
# 2        80          75        9.22     broken clouds
# 3        93         100        4.61     moderate rain
# 4        83          40       11.50  scattered clouds
# 5        74           0       12.39         clear sky
# 6        85          91        1.07   overcast clouds
# 7        66           0       31.07         clear sky
# 8        77          32        3.58        light rain
# 9        93          90        6.91   overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
